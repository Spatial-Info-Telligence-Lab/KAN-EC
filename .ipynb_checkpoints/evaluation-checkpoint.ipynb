# %%
import numpy as np
import pandas as pd

# %%
import json

# %%
mlp_results = pd.read_csv("./data/mlp_results/MLP_performance_by_year.csv")

# %%
combined_results = mlp_results[["site_ID", "mean_r2_train", "2019_test_r2", "2020_test_r2", "2021_test_r2", "2022_test_r2", "2023_test_r2", "2024_test_r2", "IGBP description", "koppen", "koppen description", "koppen_main_name", "Latitude", "Longitude", "Elevation"
]].copy()

# %%
combined_results.insert(1, "model", ["MLP" for _ in range(len(combined_results))])

# %%
combined_results
# Out:
#    site_ID model  mean_r2_train  2019_test_r2  2020_test_r2  2021_test_r2
# 0   US-xBR   MLP           0.78          0.76          0.83          0.58  \
# 1   US-xDC   MLP           0.86          0.87          0.85          0.00
# 2   US-xDJ   MLP           0.90          0.26          0.74          0.91
# 3   US-xDL   MLP           0.86          0.43          0.69          0.88
# 4   US-xDS   MLP           0.76          0.70          0.72          0.70
# 5   US-xHA   MLP           0.81          0.80          0.77          0.75
# 6   US-xKZ   MLP           0.90          0.86          0.93          0.85
# 7   US-xML   MLP           0.85          0.72          0.67          0.14
# 8   US-xNG   MLP           0.87          0.91         -0.38         -0.09
# 9   US-xRM   MLP           0.90          0.85          0.83          0.86
# 10  US-xSB   MLP           0.88          0.50          0.81          0.85
# 11  US-xSC   MLP           0.73           NaN          0.22          0.39
# ...

# %%
site_IDs = mlp_results["site_ID"].values

# %%
for site_ID in site_IDs:
    site_name = site_ID.split('-')[-1]
    r = [site_ID, "KAN"]
    d = json.load(open(f"./results/kan_{site_name}_100_results.json", "r"))

    train_r2s, test_r2s = [], []
    for y in [2019, 2020, 2021, 2022, 2023, 2024]:
        try:
            train_r2s.append(d[str(y)]["train"])
            test_r2s.append(d[str(y)]["test"])
        except:
            test_r2s.append(None)

    r.append(np.mean(train_r2s))
    r += test_r2s

    r += [None, None, None, None, None, None, None]

    combined_results.loc[len(combined_results)] = r

# %%
combined_results
# Out:
#    site_ID model  mean_r2_train  2019_test_r2  2020_test_r2  2021_test_r2
# 0   US-xBR   MLP       0.780000      0.760000      0.830000      0.580000  \
# 1   US-xDC   MLP       0.860000      0.870000      0.850000      0.000000
# 2   US-xDJ   MLP       0.900000      0.260000      0.740000      0.910000
# 3   US-xDL   MLP       0.860000      0.430000      0.690000      0.880000
# 4   US-xDS   MLP       0.760000      0.700000      0.720000      0.700000
# 5   US-xHA   MLP       0.810000      0.800000      0.770000      0.750000
# 6   US-xKZ   MLP       0.900000      0.860000      0.930000      0.850000
# 7   US-xML   MLP       0.850000      0.720000      0.670000      0.140000
# 8   US-xNG   MLP       0.870000      0.910000     -0.380000     -0.090000
# 9   US-xRM   MLP       0.900000      0.850000      0.830000      0.860000
# 10  US-xSB   MLP       0.880000      0.500000      0.810000      0.850000
# 11  US-xSC   MLP       0.730000           NaN      0.220000      0.390000
# ...

# %%
combined_results.to_csv("mlp_and_kan_results.csv")

# %%
import pandas as pd

# %%
from kan import *

# %%
n_run = 2
site_name = 'XBR'
test_year = 2019
n_epochs, n_steps = 10, 10

# %%
feature_dict = {
    'temperature': 'TA_F',
    'VPD': 'VPD_F',
    'soil moisture': 'SWC_F_MDS_1',
    'precipitation': 'P_F',
    'soil temperature': 'TS_F_MDS_1',
    'shortwave radiation': 'SW_IN_F',
}

features = list(feature_dict.values())
target_col = 'RECO_NT_VUT_REF'

# %%
torch.set_default_dtype(torch.float64)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
df = pd.read_csv(f"./data/site_data/{site_name}_clean.csv")

# Drop rows with NaNs in features or target
df_model = df.dropna(subset=features + [target_col, 'year']).copy()

train_df = df_model[df_model['year'] != test_year]
test_df = df_model[df_model['year'] == test_year]

train_input = train_df[features].values
train_label = np.log(train_df[target_col].values.reshape(-1, 1))

test_input = test_df[features].values
test_label = np.log(test_df[target_col].values.reshape(-1, 1))

dataset = {
    "train_input": torch.DoubleTensor(train_input).to(device),
    "train_label": torch.DoubleTensor(train_label).to(device),
    "test_input": torch.DoubleTensor(test_input).to(device),
    "test_label": torch.DoubleTensor(test_label).to(device)
}

# %%
model = KAN.loadckpt(f"./model/run_{n_run}/kan_{site_name}_{test_year}_{n_epochs * n_steps}_model")
#model.get_act(dataset)

# %%
model = model.prune(node_th=5e-2, edge_th=5e-2)
# Out:
# saving model version 1.11

# %%
model.plot(beta=5, scale=2.0, in_vars=list(feature_dict.values()), out_vars=['RECO'], varscale=0.2)

# %%
import json

# %%
cross_site_r2s = json.load(open(f"results/run_2/kan_cross_site_r2_100_results.json", "r"))
cross_site_rho2s = json.load(open(f"results/run_2/kan_cross_site_rho2_100_results.json", "r"))

# %%
r2_csv = [['training_site'] + list(cross_site_r2s.keys())]
rho2_csv = [['training_site'] + list(cross_site_r2s.keys())]

# %%
for site_name, site_data in cross_site_r2s.items():
    r = [site_name] + list(site_data.values())
    r2_csv.append(r)

# %%
for site_name, site_data in cross_site_rho2s.items():
    r = [site_name] + list(site_data.values())
    rho2_csv.append(r)

# %%
with open(f"results/cross-sites/kan_r2_sklearn_across_sites_leaveout.csv", "w") as o:
    for r in r2_csv:
        o.write(','.join([str(i) for i in r]) + '\n')

# %%
with open(f"results/cross-sites/kan_r2_pearson_across_sites_leaveout.csv", "w") as o:
    for r in rho2_csv:
        o.write(','.join([str(i) for i in r]) + '\n')

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
mlp_pearson = pd.read_csv("results/cross-sites/mlp_r2_pearson_across_sites.csv")
kan_pearson = pd.read_csv("results/cross-sites/kan_r2_pearson_across_sites_leaveout.csv")

# %%
mlp_pearson_numpy = mlp_pearson.iloc[:, 1:].values
kan_pearson_numpy = kan_pearson.iloc[:, 1:].values

# %%
difference = kan_pearson_numpy - mlp_pearson_numpy
df_pearson = pd.DataFrame(difference, columns=mlp_pearson.columns[1:], index=mlp_pearson.columns[1:])

# %%
df_pearson
# Out:
#           US-xBR    US-xDC    US-xDJ    US-xDL    US-xDS    US-xHA    US-xKZ
# US-xBR -0.048105 -0.130589 -0.012683  0.114364  0.184223  0.015213 -0.076355  \
# US-xDC  0.011693 -0.054723  0.110459 -0.054955  0.165722 -0.026577  0.054559
# US-xDJ -0.165484 -0.106316 -0.100045 -0.550450 -0.465296 -0.680168 -0.432396
# US-xDL  0.002083 -0.072306 -0.076415 -0.032587  0.042517  0.051865 -0.829955
# US-xDS  0.317471  0.311787  0.265474  0.043708 -0.086424  0.384857  0.142511
# US-xHA  0.362383  0.101614  0.142907  0.421249  0.523126 -0.040832  0.296873
# US-xKZ  0.010648  0.020507 -0.212837 -0.084935 -0.012209  0.101520 -0.039417
# US-xML  0.079647  0.021931 -0.335923  0.345469  0.588006  0.189970  0.413383
# US-xNG -0.149817 -0.024793 -0.161963 -0.409830 -0.405551 -0.172839 -0.125528
# US-xRM  0.098780  0.011508 -0.142020  0.403152  0.477488  0.076973 -0.459971
# US-xSB  0.013443  0.022202  0.071694  0.005154  0.048630  0.036594 -0.729983
# ...

# %%
df_pearson
# Out:
#           US-xBR    US-xDC    US-xDJ    US-xDL    US-xDS    US-xHA    US-xKZ
# US-xBR -0.043940 -0.115476 -0.015754  0.120960  0.185544  0.011052 -0.063495  \
# US-xDC  0.027145 -0.045377  0.015908 -0.084414  0.047144 -0.017185  0.007772
# US-xDJ -0.170415 -0.125887 -0.140982 -0.327747 -0.401141 -0.468867 -0.293563
# US-xDL  0.000491 -0.062398 -0.063737 -0.033899  0.064079  0.057891 -0.829906
# US-xDS  0.308617  0.302390  0.273828  0.047736 -0.084001  0.376677  0.140737
# US-xHA  0.342805  0.123515  0.199310  0.413936  0.517623 -0.043666  0.294022
# US-xKZ  0.013428  0.029582 -0.195076 -0.095761 -0.021195  0.072827 -0.039470
# US-xML  0.080041  0.024744 -0.325101  0.360837  0.594647  0.182311  0.403593
# US-xNG -0.091022 -0.026315 -0.107062 -0.293789 -0.262417 -0.234040 -0.038389
# US-xRM -0.007000 -0.217958 -0.195608 -0.019031  0.156025 -0.065900 -0.459984
# US-xSB  0.014663  0.026103  0.067418  0.002412  0.050128  0.033242 -0.008690
# ...

# %%
np.mean(df_pearson.values)
# Out:
# 0.004293688422598882

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import seaborn as sns
import numpy as np
import pandas as pd

# 2. Set up the matplotlib figure
plt.figure(figsize=(14, 10))

# 3. Create the heatmap
# 'annot=True' adds the numbers, 'fmt=".2f"' rounds them to 2 decimal places
# 'cmap="YlGnBu"' matches the Yellow-Green-Blue palette in your example
# 'linewidths=.5' adds the grid lines between cells
ax = sns.heatmap(df_pearson, 
                 annot=True, 
                 fmt=".2f", 
                 cmap="seismic_r", 
                 linewidths=.5, 
                 cbar_kws={'label': 'Pearson $r^2$ score'},
                 vmin=-1, vmax=1)

for i in range(len(df_pearson)):
    ax.add_patch(Rectangle((i, i), 1, 1, fill=False, edgecolor='red', lw=3, clip_on=False))

# 4. Customizing ticks and labels
plt.title('Performance difference across sites: pearson $r^2$', fontsize=16, pad=20)
plt.xlabel('Target site', fontsize=12)
plt.ylabel('Training site', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

# Optional: adjust layout to prevent clipping
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import seaborn as sns
import numpy as np
import pandas as pd

# 2. Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# 3. Create the heatmap
# 'annot=True' adds the numbers, 'fmt=".2f"' rounds them to 2 decimal places
# 'cmap="YlGnBu"' matches the Yellow-Green-Blue palette in your example
# 'linewidths=.5' adds the grid lines between cells
ax = sns.heatmap(df_pearson, 
                 annot=True, 
                 fmt=".2f", 
                 cmap="seismic_r", 
                 linewidths=.5, 
                 cbar_kws={'label': 'Pearson $r^2$ score'},
                 vmin=-1, vmax=1)

for i in range(len(df_pearson)):
    ax.add_patch(Rectangle((i, i), 1, 1, fill=False, edgecolor='red', lw=3, clip_on=False))

# 4. Customizing ticks and labels
plt.title('Performance difference across sites: pearson $r^2$', fontsize=16, pad=20)
plt.xlabel('Target site', fontsize=12)
plt.ylabel('Training site', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

# Optional: adjust layout to prevent clipping
plt.tight_layout()

plt.show()

# %%
perf_label = np.ones_like(mlp_pearson_numpy) * mlp_pearson_numpy.diagonal().reshape((-1, 1))

# %%
igbp_int = {'CVM': 'red', 'CRO': 'orange', 'DBF': 'yellow', 'MF': 'green', 'GRA': 'blue', 'ENF': 'purple', 'WET': 'black'}

# %%
igbp = ['DBF',
'GRA',
'ENF',
'MF',
'CVM',
'DBF',
'GRA',
'DBF',
'GRA',
'ENF',
'ENF',
'DBF',
'DBF',
'CRO',
'DBF',
'WET',
'DBF',
'DBF',
'MF',
'GRA',
'ENF',
]

# %%
igbp = [igbp_int[i] for i in igbp]

# %%
igbp_array = np.array([igbp for _ in range(len(igbp))]).T

# %%
igbp_train_label = igbp_array

# %%
igbp_test_label = igbp_array.T

# %%
plt.figure(figsize=(10,10))
plt.title("MLP Pearson v.s. KAN Pearson, colored by training performance")
plt.plot(np.arange(0,1.1,0.1), np.arange(0,1.1,0.1), c='red')
plt.scatter(mlp_pearson_numpy.flatten(), kan_pearson_numpy.flatten(), c=perf_label.flatten())
plt.colorbar()

# %%
igbp_int = {'CVM': 'red', 'CRO': 'orange', 'DBF': 'yellow', 'MF': 'green', 'GRA': 'blue', 'ENF': 'purple', 'WET': 'black'}

# %%
plt.figure(figsize=(10,10))
plt.title("MLP Pearson v.s. KAN Pearson, colored by training IGBP")
plt.plot(np.arange(0,1.1,0.1), np.arange(0,1.1,0.1), c='red')
plt.scatter(mlp_pearson_numpy.flatten(), kan_pearson_numpy.flatten(), c=igbp_train_label.flatten())

# %%
igbp_int = {'CVM': 'red', 'CRO': 'orange', 'DBF': 'yellow', 'MF': 'green', 'GRA': 'blue', 'ENF': 'purple', 'WET': 'black'}

# %%
plt.figure(figsize=(10,10))
plt.title("MLP Pearson v.s. KAN Pearson, colored by test IGBP")
plt.plot(np.arange(0,1.1,0.1), np.arange(0,1.1,0.1), c='red')
plt.scatter(mlp_pearson_numpy.flatten(), kan_pearson_numpy.flatten(), c=igbp_test_label.flatten())

# %%
mlp_sklearn = pd.read_csv("results/cross-sites/mlp_r2_sklearn_across_sites.csv")
kan_sklearn = pd.read_csv("results/cross-sites/kan_r2_sklearn_across_sites.csv")

# %%
mlp_sklearn_numpy = np.clip(mlp_sklearn.iloc[:, 1:].values, 0, None)
kan_sklearn_numpy = np.clip(kan_sklearn.iloc[:, 1:].values, 0, None)

difference = kan_sklearn_numpy - mlp_sklearn_numpy
df_sklearn = pd.DataFrame(difference, columns=mlp_sklearn.columns[1:], index=mlp_sklearn.columns[1:])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# 2. Set up the matplotlib figure
plt.figure(figsize=(15, 10))

# 3. Create the heatmap
# 'annot=True' adds the numbers, 'fmt=".2f"' rounds them to 2 decimal places
# 'cmap="YlGnBu"' matches the Yellow-Green-Blue palette in your example
# 'linewidths=.5' adds the grid lines between cells
ax = sns.heatmap(df_sklearn, 
                 annot=True, 
                 fmt=".2f", 
                 cmap="seismic_r", 
                 linewidths=.5, 
                 cbar_kws={'label': 'Pearson $r^2$ score'},
                 vmin=-1, vmax=1)

# 4. Customizing ticks and labels
plt.title('Performance difference across sites: sklearn $R^2$', fontsize=16, pad=20)
plt.xlabel('Target site', fontsize=12)
plt.ylabel('Training site', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

# Optional: adjust layout to prevent clipping
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# 2. Set up the matplotlib figure
plt.figure(figsize=(15, 10))

# 3. Create the heatmap
# 'annot=True' adds the numbers, 'fmt=".2f"' rounds them to 2 decimal places
# 'cmap="YlGnBu"' matches the Yellow-Green-Blue palette in your example
# 'linewidths=.5' adds the grid lines between cells
ax = sns.heatmap(mlp_sklearn.iloc[:,1:], 
                 annot=True, 
                 fmt=".2f", 
                 cmap="seismic_r", 
                 linewidths=.5, 
                 cbar_kws={'label': 'Pearson $r^2$ score'},
                 vmin=-1, vmax=1)

# 4. Customizing ticks and labels
plt.title('Performance difference across sites: sklearn $R^2$', fontsize=16, pad=20)
plt.xlabel('Target site', fontsize=12)
plt.ylabel('Training site', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

# Optional: adjust layout to prevent clipping
plt.tight_layout()

plt.show()
